# %% [markdown]
# ## **Dermatology Diseases Dataset**
#
# Nama: Muhamad Indra
# NIM : 14230008
# Kelas:14.1B.01
# Program S2 Nusa mandiri

# %% [markdown]
# ### 1. Dataset

# %% [markdown]
# #### - Dari mana diambil
#
# Pasien pertama kali dievaluasi secara klinis dengan 12 fitur. Setelah itu, sampel kulit diambil untuk evaluasi 22 gambaran histopatologi. Nilai ciri histopatologi ditentukan dengan analisis sampel di bawah mikroskop.
#
# Dataset ini kemudian digunakan dalam penelitian yang diterbitkan oleh Nilsel Ilter dan H. Guvenir  dibawah lisensi  Creative Commons Attribution 4.0 International (CC BY 4.0) license untuk menjelaskan metode klasifikasi penyakit kulit berdasarkan diagnosisnya yang kemudian dipublikasikan ke halaman website https://archive.ics.uci.edu/dataset/33/dermatology.
#
#
# #### - Bagaimana proses pengambilan datanya
#
# Dalam proses pengambilan data itu sendiri dengan cara mengunduh dataset tersebut melalui link https://archive.ics.uci.edu/dataset/33/dermatology.
#
# #### - Jumlah sample data
#
# Pada dataset deramtology ini memiliki total 366 sampel data
#
# #### - Jumlah fitur
# Untuk jumlah fiturnya sendiri dataset dermatology ini memiliki 34 feature data yang terbagi dalam 2 kategori.  Berikut fitur-fitur yang terdapat dalam dataset diantaranya:
#    - Clinical Attributes: (take values 0, 1, 2, 3, unless otherwise indicated)
#       1. erythema
#       2. scaling
#       3. definite borders
#       4. itching
#       5. koebner phenomenon
#       6. polygonal papules
#       7. follicular papules
#       8. oral mucosal involvement
#       9. knee and elbow involvement
#      10. scalp involvement
#      11. family history, (0 or 1)
#      34. Age (linear)
#
#    - Histopathological Attributes: (take values 0, 1, 2, 3)
#      12. melanin incontinence
#      13. eosinophils in the infiltrate
#      14. PNL infiltrate
#      15. fibrosis of the papillary dermis
#      16. exocytosis
#      17. acanthosis
#      18. hyperkeratosis
#      19. parakeratosis
#      20. clubbing of the rete ridges
#      21. elongation of the rete ridges
#      22. thinning of the suprapapillary epidermis
#      23. spongiform pustule
#      24. munro microabcess
#      25. focal hypergranulosis
#      26. disappearance of the granular layer
#      27. vacuolisation and damage of basal layer
#      28. spongiosis
#      29. saw-tooth appearance of retes
#      30. follicular horn plug
#      31. perifollicular parakeratosis
#      32. inflammatory monoluclear inflitrate
#      33. band-like infiltrate
#
# #### - Distribusi kelas
# Untuk distribusi kelas itu sendiri dalam dataset dermatology ini dapat dilakukan pengelompokkan data berdasarkan Class yang terdapat dalam dataset tersebut diantaranya:
#
#
#     Class code:   Class:                  Number of instances:
#            1      psoriasis			             112
#            2      seboreic dermatitis             61
#            3      lichen planus                   72
#            4      pityriasis rosea                49
#            5      cronic dermatitis               52
#            6      pityriasis rubra pilaris        20

# %% [markdown]
# ## 2. Explorasi dan visualisasi dataset

# %% [markdown]
# #### Import Modules

# %%
import numpy as np
import pandas as pd 
from pandas import Series, DataFrame

import plotly.graph_objs as go 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot 
init_notebook_mode(connected=True)

import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[15,5]
from scipy import stats
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Load the Dataset

# %%
df = pd.read_csv("https://raw.githubusercontent.com/MuhamadIndra10/machine-learning/main/dermatology.csv")

# %% [markdown]
# #### Tampilkan 10 data pertama

# %%
df.head(10)
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
# 5         2        3                 2        0                   0
# 6         2        1                 0        2                   0
# 7         2        2                 3        3                   3
# 8         2        2                 1        0                   2
# 9         2        2                 1        0                   1
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# ...

# %%
df.shape
# Out:
# (366, 35)

# %% [markdown]
# ### Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   erythema                             366 non-null    int64
#  1   scaling                              366 non-null    int64
#  2   definite_borders                     366 non-null    int64
#  3   itching                              366 non-null    int64
#  4   koebner_phenomenon                   366 non-null    int64
#  5   polygonal_papules                    366 non-null    int64
#  6   follicular_papules                   366 non-null    int64
#  7   oral_mucosal_involvement             366 non-null    int64
#  8   knee_and_elbow_involvement           366 non-null    int64
#  9   scalp_involvement                    366 non-null    int64
#  10  family_history                       366 non-null    int64
# ...

# %%
df.isna().sum()
# Out:
# erythema                               0
# scaling                                0
# definite_borders                       0
# itching                                0
# koebner_phenomenon                     0
# polygonal_papules                      0
# follicular_papules                     0
# oral_mucosal_involvement               0
# knee_and_elbow_involvement             0
# scalp_involvement                      0
# family_history                         0
# melanin_incontinence                   0
# eosinophils_infiltrate                 0
# PNL_infiltrate                         0
# fibrosis_papillary_dermis              0
# exocytosis                             0
# acanthosis                             0
# hyperkeratosis                         0
# parakeratosis                          0
# clubbing_rete_ridges                   0
# elongation_rete_ridges                 0
# thinning_suprapapillary_epidermis      0
# spongiform_pustule                     0
# ...

# %%
age_values_with_question_mark = df[df['age'] == '?']
age_values_with_question_mark
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 33          2        2                 1        0                   0
# 34          2        1                 0        0                   2
# 35          2        2                 1        2                   0
# 36          2        1                 2        3                   2
# 262         2        1                 0        2                   0
# 263         1        1                 1        3                   0
# 264         1        1                 0        2                   0
# 265         1        1                 0        3                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 33                   0                   0                         0
# 34                   0                   0                         0
# 35                   0                   0                         0
# ...

# %%
df['age'] = df['age'].replace('?', np.nan)  # Replace '?' with NaN

# we remove rows with NaN values in the 'age' column using dropna() function
df.dropna(subset=['age'], inplace=True)

# %%
age_values_with_question_mark = df[df['age'] == '?']
age_values_with_question_mark
# Out:
# Empty DataFrame
# Columns: [erythema, scaling, definite_borders, itching, koebner_phenomenon, polygonal_papules, follicular_papules, oral_mucosal_involvement, knee_and_elbow_involvement, scalp_involvement, family_history, melanin_incontinence, eosinophils_infiltrate, PNL_infiltrate, fibrosis_papillary_dermis, exocytosis, acanthosis, hyperkeratosis, parakeratosis, clubbing_rete_ridges, elongation_rete_ridges, thinning_suprapapillary_epidermis, spongiform_pustule, munro_microabcess, focal_hypergranulosis, disappearance_granular_layer, vacuolisation_damage_basal_layer, spongiosis, saw_tooth_appearance_retes, follicular_horn_plug, perifollicular_parakeratosis, inflammatory_mononuclear_infiltrate, band_like_infiltrate, age, class]
# Index: []
#
# [0 rows x 35 columns]

# %%
df['class'].value_counts()
# Out:
# class
# 1    111
# 3     71
# 2     60
# 5     48
# 4     48
# 6     20
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# erythema                                int64
# scaling                                 int64
# definite_borders                        int64
# itching                                 int64
# koebner_phenomenon                      int64
# polygonal_papules                       int64
# follicular_papules                      int64
# oral_mucosal_involvement                int64
# knee_and_elbow_involvement              int64
# scalp_involvement                       int64
# family_history                          int64
# melanin_incontinence                    int64
# eosinophils_infiltrate                  int64
# PNL_infiltrate                          int64
# fibrosis_papillary_dermis               int64
# exocytosis                              int64
# acanthosis                              int64
# hyperkeratosis                          int64
# parakeratosis                           int64
# clubbing_rete_ridges                    int64
# ...

# %%
df['age'] = df['age'].astype(float).astype(pd.Int64Dtype())  # Convert to float and then to integer

# %%
df.dtypes
# Out:
# erythema                               int64
# scaling                                int64
# definite_borders                       int64
# itching                                int64
# koebner_phenomenon                     int64
# polygonal_papules                      int64
# follicular_papules                     int64
# oral_mucosal_involvement               int64
# knee_and_elbow_involvement             int64
# scalp_involvement                      int64
# family_history                         int64
# melanin_incontinence                   int64
# eosinophils_infiltrate                 int64
# PNL_infiltrate                         int64
# fibrosis_papillary_dermis              int64
# exocytosis                             int64
# acanthosis                             int64
# hyperkeratosis                         int64
# parakeratosis                          int64
# clubbing_rete_ridges                   int64
# elongation_rete_ridges                 int64
# ...

# %% [markdown]
# ### Statistik (Jumlah data setiap kelas) dari dataset tersebut dalam Bar Chart

# %%
# Plot a bar plot of the 'class' column
class_counts = df['class'].value_counts()
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class Distribution')
plt.show()

# %%
total = df['class'].value_counts().values.sum()
# df['class_name'] = 'na'
# df.loc[df["class"] == 1, 'class_name'] = 'psoriasis'
# df.loc[df["class"] == 2, 'class_name'] = 'seboreic dermatitis'
# df.loc[df["class"] == 3, 'class_name'] = 'lichen planus'
# df.loc[df["class"] == 4, 'class_name'] = 'pityriasis rosea'
# df.loc[df["class"] == 5, 'class_name'] = 'cronic dermatitis'
# df.loc[df["class"] == 6, 'class_name'] = 'pityriasis rubra pilaris'

def fmt(x):
    return '{:.1f}%\n{:.0f}'.format(x, total*x/100)

data = df["class"].value_counts()
ax = data.plot(kind="pie", autopct=fmt, shadow=True, legend=True, title='Class Distribution', ylabel='', labeldistance=None)
ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
plt.show()

# %%
clinical_attributes = df.iloc[:, :-1]
clinical_attributes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358 entries, 0 to 365
# Data columns (total 34 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   erythema                             358 non-null    int64
#  1   scaling                              358 non-null    int64
#  2   definite_borders                     358 non-null    int64
#  3   itching                              358 non-null    int64
#  4   koebner_phenomenon                   358 non-null    int64
#  5   polygonal_papules                    358 non-null    int64
#  6   follicular_papules                   358 non-null    int64
#  7   oral_mucosal_involvement             358 non-null    int64
#  8   knee_and_elbow_involvement           358 non-null    int64
#  9   scalp_involvement                    358 non-null    int64
#  10  family_history                       358 non-null    int64
# ...

# %% [markdown]
# ### Statistik (Mean, Median, Mode, Standard Deviation, dan Kuartil) dari setiap fitur data.

# %%
# Select the first 10 columns
selected_columns = df.iloc[:, :10]
data = selected_columns

# Menampilkan tabel statistik
print("Statistik Data Dermatology:")
# df = pd.DataFrame(statistics)

# Menampilkan DataFrame sebagai tabel
data.describe()
# Out:
# Statistik Data Dermatology:
#          erythema     scaling  definite_borders     itching  \
# count  358.000000  358.000000        358.000000  358.000000
# mean     2.078212    1.807263          1.569832    1.354749
# std      0.664865    0.701541          0.900909    1.135062
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.750000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          358.000000         358.000000          358.000000
# mean             0.636872           0.449721            0.170391
# std              0.908709           0.956468            0.576394
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %% [markdown]
# ### Plot Histogram

# %%
# selected_columns = df.iloc[:, :10]

selected_columns = df.iloc[:, :-2]
selected_columns.hist(bins=10, linewidth=1.2)
fig = plt.gcf()
fig.set_size_inches(25,20)
plt.show()

# %% [markdown]
# Converting class values to start from 0 (prerequisite for XGBoost model)

# %%
le = LabelEncoder()
df['class'] = le.fit_transform(df['class'])

# %%
df['class'].value_counts()
# Out:
# class
# 0    111
# 2     71
# 1     60
# 4     48
# 3     48
# 5     20
# Name: count, dtype: int64

# %% [markdown]
# ### Correlation Analisys

# %%
# see correlation between variables through a correlation heatmap
corr = df.corr()
plt.figure(figsize=(20,15))
sns.heatmap(corr, annot=True ,fmt='.2f').set(title='Heatmap of all cols')
plt.show()

# %%
df.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_infiltrate', 'PNL_infiltrate', 'fibrosis_papillary_dermis',
#        'exocytosis', 'acanthosis', 'hyperkeratosis', 'parakeratosis',
#        'clubbing_rete_ridges', 'elongation_rete_ridges',
#        'thinning_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_granular_layer', 'vacuolisation_damage_basal_layer',
#        'spongiosis', 'saw_tooth_appearance_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_mononuclear_infiltrate',
#        'band_like_infiltrate', 'age', 'class'],
#       dtype='object')

# %% [markdown]
# ### Dropping the columns with correlation between (-0.1, 0.1)

# %%
df.drop(['itching', 'koebner_phenomenon', 'polygonal_papules', 'oral_mucosal_involvement', 'melanin_incontinence',
        'eosinophils_infiltrate', 'acanthosis', 'hyperkeratosis', 'focal_hypergranulosis', 
        'vacuolisation_damage_basal_layer',
        'saw_tooth_appearance_retes', 'inflammatory_mononuclear_infiltrate', 'band_like_infiltrate'], axis=1, inplace=True)

# %%
fig= plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), annot=True ,fmt='.2f').set(title='Heatmap of shortlisted cols')
plt.show()

# %% [markdown]
# ## 3. Explorasi penerapan metode machine learning konvensional  Train Model and Predict

# %%
import numpy as np
import pandas as pd 
from pandas import Series, DataFrame

from sklearn.model_selection import train_test_split # to split the dataset for training and testing 
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier # KNN classifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics # for checking the model accuracy
from sklearn.model_selection import GridSearchCV
from sklearn import model_selection

# %% [markdown]
# ## Konfigurasi default dari setiap model

# %%
df.shape
# Out:
# (358, 22)

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# ## Splitting The Data into Training And Testing Dataset

# %%
# the attribute test_size=0.2 splits the data into 80% and 20% ratio. train=80% and test=20%
minmax = MinMaxScaler()
train_X,test_X,train_y,test_y = train_test_split(x,y,test_size=0.20,random_state=42)
train_X = minmax.fit_transform(train_X)
test_X = minmax.transform(test_X)
print(train_X.shape)
print(test_X.shape)

# Define stratified k-fold cross-validation with 10 splits
kfold = model_selection.KFold(n_splits=10, shuffle=True, random_state=42)
scoring = 'accuracy'
# Out:
# (286, 21)
# (72, 21)

# %% [markdown]
# ### Naive Baiyes

# %%
model = GaussianNB() # select the svm algorithm

# we train the algorithm with training data and training output
model.fit(train_X, train_y)

# we pass the testing data to the stored algorithm to predict the outcome
prediction = model.predict(test_X)

# Evaluate the model's performance
print('The accuracy of the Naive Baiyes is: ', metrics.accuracy_score(prediction, test_y),"\r\n") 
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)
# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of the Naive Baiyes is:  0.6805555555555556
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       0.80      0.29      0.42        14
#            2       1.00      0.14      0.25        14
#            3       0.29      1.00      0.44         8
#            4       0.85      0.92      0.88        12
#            5       1.00      1.00      1.00         2
#
#     accuracy                           0.68        72
#    macro avg       0.82      0.72      0.67        72
# weighted avg       0.86      0.68      0.66        72
#
# Cross-Validation Score 10-Fold: 0.7066502463054187

# %% [markdown]
# ### Decision Tree

# %%
model = DecisionTreeClassifier()
model.fit(train_X, train_y)
prediction = model.predict(test_X)
print('The accuracy of Decision Tree is: ', metrics.accuracy_score(prediction, test_y),"\r\n")
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)

# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of Decision Tree is:  0.8472222222222222
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       0.83      0.71      0.77        14
#            2       0.83      0.71      0.77        14
#            3       0.60      0.75      0.67         8
#            4       0.86      1.00      0.92        12
#            5       1.00      0.50      0.67         2
#
#     accuracy                           0.85        72
#    macro avg       0.85      0.78      0.80        72
# weighted avg       0.85      0.85      0.84        72
#
# Cross-Validation Score 10-Fold: 0.8501231527093596

# %% [markdown]
# ### K-Nearest Neighbors

# %%
model = KNeighborsClassifier(n_neighbors=10) # this examines 3 neighbors for putting the data into class
model.fit(train_X, train_y)
prediction = model.predict(test_X)

print('The accuracy of KNN is: ', metrics.accuracy_score(prediction, test_y),"\r\n")
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)

# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of KNN is:  0.8472222222222222
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        22
#            1       1.00      0.71      0.83        14
#            2       0.69      0.79      0.73        14
#            3       0.50      0.75      0.60         8
#            4       1.00      1.00      1.00        12
#            5       1.00      1.00      1.00         2
#
#     accuracy                           0.85        72
#    macro avg       0.86      0.86      0.85        72
# weighted avg       0.88      0.85      0.86        72
#
# Cross-Validation Score 10-Fold: 0.8501231527093596

# %% [markdown]
# ### Support Vector Machine SVM

# %%
model = SVC() # select the svm algorithm

# we train the algorithm with training data and training output
model.fit(train_X, train_y)

# we pass the testing data to the stored algorithm to predict the outcome
prediction = model.predict(test_X)

# Evaluate the model's performance
print('The accuracy of the SVM is: ', metrics.accuracy_score(prediction, test_y),"\r\n")
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)

# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of the SVM is:  0.9305555555555556
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       1.00      0.86      0.92        14
#            2       0.87      0.93      0.90        14
#            3       0.67      0.75      0.71         8
#            4       1.00      1.00      1.00        12
#            5       1.00      1.00      1.00         2
#
#     accuracy                           0.93        72
#    macro avg       0.92      0.92      0.92        72
# weighted avg       0.94      0.93      0.93        72
#
# Cross-Validation Score 10-Fold: 0.8705665024630542

# %% [markdown]
# ### Logistic Regression

# %%
model = LogisticRegression()
model.fit(train_X, train_y)
prediction = model.predict(test_X)
print('The accuracy of Logistic Regression is: ', metrics.accuracy_score(prediction, test_y),"\r\n")
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)

# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of Logistic Regression is:  0.875
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        22
#            1       1.00      0.86      0.92        14
#            2       0.71      0.86      0.77        14
#            3       0.50      0.50      0.50         8
#            4       1.00      1.00      1.00        12
#            5       1.00      1.00      1.00         2
#
#     accuracy                           0.88        72
#    macro avg       0.87      0.86      0.86        72
# weighted avg       0.89      0.88      0.88        72
#
# Cross-Validation Score 10-Fold: 0.8460591133004927

# %% [markdown]
# ### XGBoost

# %%
model = XGBClassifier()
model.fit(train_X, train_y)
prediction = model.predict(test_X)
print('The accuracy of XGBoost is: ', metrics.accuracy_score(prediction, test_y),"\r\n")
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)

# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of XGBoost is:  0.9166666666666666
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       1.00      0.79      0.88        14
#            2       0.81      0.93      0.87        14
#            3       0.75      0.75      0.75         8
#            4       0.92      1.00      0.96        12
#            5       1.00      1.00      1.00         2
#
#     accuracy                           0.92        72
#    macro avg       0.91      0.91      0.91        72
# weighted avg       0.92      0.92      0.92        72
#
# Cross-Validation Score 10-Fold: 0.8671182266009853

# %% [markdown]
# ### Adaboost

# %%
model = AdaBoostClassifier() 
model.fit(train_X, train_y)
prediction = model.predict(test_X)
print('The accuracy of Adaboost is: ', metrics.accuracy_score(prediction, test_y),"\r\n")
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)

# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of Adaboost is:  0.5694444444444444
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        22
#            1       0.00      0.00      0.00        14
#            2       0.34      0.86      0.49        14
#            3       0.00      0.00      0.00         8
#            4       0.86      1.00      0.92        12
#            5       0.14      0.50      0.22         2
#
#     accuracy                           0.57        72
#    macro avg       0.39      0.51      0.41        72
# weighted avg       0.52      0.57      0.51        72
#
# Cross-Validation Score 10-Fold: 0.6365763546798029

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestClassifier() 
model.fit(train_X, train_y)
prediction = model.predict(test_X)
print('The accuracy of Adaboost is: ', metrics.accuracy_score(prediction, test_y),"\r\n")
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)

# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of Adaboost is:  0.9027777777777778
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       1.00      0.79      0.88        14
#            2       0.86      0.86      0.86        14
#            3       0.70      0.88      0.78         8
#            4       0.92      1.00      0.96        12
#            5       1.00      0.50      0.67         2
#
#     accuracy                           0.90        72
#    macro avg       0.91      0.84      0.85        72
# weighted avg       0.91      0.90      0.90        72
#
# Cross-Validation Score 10-Fold: 0.9028325123152708

# %% [markdown]
# ### GradientBoosting

# %%
model = GradientBoostingClassifier() 
model.fit(train_X, train_y)
prediction = model.predict(test_X)
print('The accuracy of GradientBoosting is: ', metrics.accuracy_score(prediction, test_y),"\r\n")
print(metrics.classification_report(test_y, prediction))

# Perform cross-validation
cv_scores = model_selection.cross_val_score(model, train_X, train_y, cv=kfold,  scoring=scoring)

# Menampilkan rata-rata skor validasi silang
print("Cross-Validation Score 10-Fold:", cv_scores.mean())
# Out:
# The accuracy of GradientBoosting is:  0.9027777777777778
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       1.00      0.86      0.92        14
#            2       0.85      0.79      0.81        14
#            3       0.67      0.75      0.71         8
#            4       0.86      1.00      0.92        12
#            5       1.00      1.00      1.00         2
#
#     accuracy                           0.90        72
#    macro avg       0.89      0.90      0.89        72
# weighted avg       0.91      0.90      0.90        72
#
# Cross-Validation Score 10-Fold: 0.8746305418719211

# %% [markdown]
# ### 3.1.3 Apakah ada perbedaan antara train test split dan 10-fold cross validation? Mengapa?

# %% [markdown]
# 1. **Naive Bayes**
#     - Akurasi Dari Train Test Split: **0.6805555555555556**
#     - Skor Cross Validation 10-Fold: **0.7066502463054187**
#
#
# 2. **Decision Tree**
#     - Akurasi Dari Train Test Split: **0.8472222222222222**
#     - Skor Cross Validation 10-Fold: **0.8501231527093596**
#
#
# 3. **K-Nearest Neighbors (KNN)**
#     - Akurasi Dari Train Test Split: **0.8472222222222222**
#     - Skor Cross Validation 10-Fold: **0.8501231527093596**
#
#
# 4. **Support Vector Machine (SVM)**
#     - Akurasi Dari Train Test Split: **0.9305555555555556**
#     - Skor Cross Validation 10-Fold: **0.8705665024630542**
#
#
# 5. **Logistic Regression**
#     - Akurasi Dari Train Test Split: **0.875**
#     - Skor Cross Validation 10-Fold: **0.8460591133004927**
#
#
# 6. **XGBoost**
#     - Akurasi Dari Train Test Split: **0.9166666666666666**
#     - Skor Cross Validation 10-Fold: **0.8671182266009853**
#
#
# 7. **AdaBoost**
#     - Akurasi Dari Train Test Split: **0.7941176470588235**
#     - Skor Cross Validation 10-Fold: **0.6365763546798029**
#
#
# 8. **Random Forest**
#     - Akurasi Dari Train Test Split: **0.9027777777777778**
#     - Skor Cross Validation 10-Fold: **0.9028325123152708**
#
#
# 9. **Gradien Boosting**
#     - Akurasi Dari Train Test Split: **0.9027777777777778**
#     - Skor Cross Validation 10-Fold: **0.8746305418719211**
#
# Ya, terdapat perbedaan antara Train-Test Split dan 10-Fold Cross Validation dalam hal ini ada beberapa hasil accuracy model algoritma konvensional mengalami kenaikan pada nilai accuraynya ada juga mengalamai penurunan.Ada beberapa hal yang menyebabkan adanya perbedaan antara Train-Test Split dan 10-Fold Cross Validation. Berikut adalah beberapa alasan yang mungkin menyebabkan perbedaan tersebut:
#
# 1. **Variabilitas dalam Data**
# Setiap kali data dibagi menjadi set pelatihan dan pengujian, subset tertentu dari data digunakan untuk melatih model dan subset lainnya untuk menguji model. Variabilitas dalam data itu sendiri dapat menyebabkan perbedaan dalam hasil model.
#
# 2. **Variabilitas dalam Pembagian Data**
# Cross-validation dan split train-test membagi data ke dalam subset. Metode yang digunakan untuk membagi data ini dapat menghasilkan hasil yang agak berbeda tergantung pada cara data diacak atau dibagi.
#
# 3. **Jumlah Data yang Digunakan**
# Pembagian uji pelatihan menggunakan satu pemisahan, sedangkan pemisahan uji pelatihan menggunakan seluruh dataset untuk pelatihan dan pengujian dalam beberapa iterasi. Oleh karena itu, cross-validation menggunakan lebih banyak data uji dan pelatihan, sehingga lebih mudah untuk melihat variasi dalam performa model.
#
# 4. **Perbandingan Kinerja Model**
# Penilaian performa model dapat berbeda jika model Anda sensitif terhadap pembagian data. Ini dapat terjadi jika ada perbedaan pembagian antara cross-validation dan split train-test.
#
# 5. **Overfitting atau Underfitting**
# Jika model Anda memiliki kecenderungan untuk terlalu cocok atau terlalu tidak cocok dengan bagian data tertentu, perbedaan dalam pembagian dapat menyebabkan tingkat kecocokan model berbeda.
#
# 6. **Ukuran Sampel yang Kecil**
# Perubahan dalam jumlah sampel yang digunakan untuk pelatihan dan pengujian dapat berdampak lebih besar pada hasil model pada dataset yang lebih kecil.
#
# 7. **Pemilihan Metrik Evaluasi**
# Tergantung pada pembagian data dan metrik yang digunakan, metrik evaluasi yang digunakan untuk mengukur akurasi atau kinerja lainnya dapat menghasilkan nilai yang berbeda.
#
# 8. **Keberuntungan**
# Mungkin ada perbedaan dalam hasil karena pembagian data acak atau faktor keberuntungan.

# %% [markdown]
# ### Hyperparameter tuning

# %% [markdown]
# ### 3.2 Dari masing-masing metode machine learning, tuning, minimal 5 nilai hyper-parameternya

# %%
nb = GaussianNB()
dt = DecisionTreeClassifier()
knn = KNeighborsClassifier()
svc = SVC()
lr = LogisticRegression()
xgb = XGBClassifier()
adb = AdaBoostClassifier()
rf = RandomForestClassifier()
gb = GradientBoostingClassifier()

# Define stratified k-fold cross-validation with 10 splits
kfold = model_selection.KFold(n_splits=10, shuffle=True, random_state=42)
scoring = 'accuracy'

# %%
print('nb',nb.get_params())
print()
print('dt',dt.get_params())
print()
print('knn',knn.get_params())
print()
print('svc',svc.get_params())
print()
print('lr',lr.get_params()) 
print()
print('xgb',xgb.get_params())
print()
print('adb',adb.get_params())
print()
print('rf',rf.get_params())
print()
print('gb',gb.get_params())
# Out:
# nb {'priors': None, 'var_smoothing': 1e-09}
#
# dt {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
#
# knn {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
#
# svc {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#
# ...

# %% [markdown]
# ### Naive Baiyes

# %%
# Define hyperparameter grid for Decision Tree
param_grid = {
    'priors': [None, [0.2, 0.8], [0.5, 0.5]],
    'var_smoothing': [1e-09, 1e-08, 1e-07]
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=nb, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values
best_params = grid_search.best_params_
best_score_ = grid_search.best_score_
print("Best Hyperparameters:", best_params)

# The accuracies
print("Best score accuracy for Naive Bayes hyperparameter tuning:", best_score_)
# Out:
# Best Hyperparameters: {'priors': None, 'var_smoothing': 1e-07}
# Best score accuracy for Naive Bayes hyperparameter tuning: 0.7273399014778325

# %% [markdown]
# ### Decision Tree

# %%
# Define hyperparameter grid for Decision Tree
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2', None]
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=dt, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values for Decision Tree
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Hyperparameters for Decision Tree:", best_params)

# The accuracies
print("Best score accuracy for Decision Tree hyperparameter tuning:", best_score)
# Out:
# Best Hyperparameters for Decision Tree: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best score accuracy for Decision Tree hyperparameter tuning: 0.8640394088669952

# %% [markdown]
# ### K-Nearest Neighbors

# %%
# Define hyperparameter grid for KNeighborsClassifier
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'p': [1, 2],
    'leaf_size': [10, 20, 30, 40]
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Hyperparameters:", best_params)

# The accuracies
print("Best score accuracy for KNN hyperparameter tuning:", best_score)
# Out:
# Best Hyperparameters: {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# Best score accuracy for KNN hyperparameter tuning: 0.8746305418719211

# %% [markdown]
# ### Support Vectore Machine

# %%
# Define hyperparameter grid
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'poly', 'rbf'],
    'degree': [2, 3],
    'gamma': [0.1, 1, 'auto'],
    'class_weight': [None, 'balanced']
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Hyperparameters:", best_params)

# The accuracies
print("Best score accuracy for SVM hyperparameter tuning:", best_score)
# Out:
# Best Hyperparameters: {'C': 1, 'class_weight': 'balanced', 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Best score accuracy for SVM hyperparameter tuning: 0.8812462189957653

# %% [markdown]
# ### Logistic Regression

# %%
# Define hyperparameter grid
param_grid = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],  # Regularization type
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Inverse of regularization strength
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],  # Algorithm to use in the optimization problem
    'max_iter': [100, 500, 1000]  # Maximum number of iterations for optimization
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=lr, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Hyperparameters:", best_params)

# Make predictions
predictions = grid_search.best_estimator_.predict(test_X)

# Calculate accuracy for each model
accuracy = metrics.accuracy_score(test_y, predictions)

# Compare the accuracies
print("Best score accuracy for Logistic Regression hyperparameter tuning:", best_score , accuracy)
# Out:
# Best Hyperparameters: {'C': 0.001, 'max_iter': 1000, 'penalty': 'none', 'solver': 'saga'}
# Best score accuracy for Logistic Regression hyperparameter tuning: 0.8602216748768473 0.9166666666666666

# %% [markdown]
# ### XGBoost

# %%
# Define hyperparameter grid
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    'gamma': [0, 0.1, 0.2]
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Hyperparameters:", best_params)

# The accuracies
print("Accuracy for XGBoost hyperparameter tuning:", best_score)
# Out:
# Best Hyperparameters: {'gamma': 0.2, 'learning_rate': 0.2, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100}
# Accuracy for XGBoost hyperparameter tuning: 0.9020568663036903

# %% [markdown]
# ### AdaBoost

# %%
# Define hyperparameter grid
param_grid = {
    'learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0],
    'n_estimators': [10, 50, 100, 500],
    'algorithm': ["SAMME.R"],
    'random_state': [42],
    'base_estimator': [DecisionTreeClassifier(max_depth=1)]
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=adb, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Hyperparameters:", best_params)

# The accuracies
print("Best score accuracy for Adaboost hyperparameter tuning:", best_score)
# Out:
# Best Hyperparameters: {'algorithm': 'SAMME.R', 'base_estimator': DecisionTreeClassifier(max_depth=1), 'learning_rate': 0.1, 'n_estimators': 500, 'random_state': 42}
# Best score accuracy for Adaboost hyperparameter tuning: 0.7448275862068965

# %% [markdown]
# ### Random Forest

# %%
# Define hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Hyperparameters:", best_params)

# The accuracies
print("Best Score accuracy for Random Forest hyperparameter tuning:", best_score)
# Out:
# Best Hyperparameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy for Random Forest hyperparameter tuning: 0.9722222222222222

# %% [markdown]
# ### Gradient Boosting

# %%
# Define hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 150],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2'],
    'max_depth': [3, 5, 7]
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=kfold, scoring=scoring)
grid_search.fit(train_X, train_y)

# Print the best hyperparameter values
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Hyperparameters:", best_params)

# Compare the accuracies
print("Best Score accuracy for Gradient Boosting hyperparameter tuning:", best_score)
# Out:
# Best Hyperparameters: {'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# Best Score accuracy for Gradient Boosting hyperparameter tuning: 0.8988916256157635

# %% [markdown]
# ### 3.2.1  Bandingkan setiap metode dengan setting 5 nilai hyper-parameternya. Mana yang terbaik dari setiap metode? Jelaskan mengapa?

# %% [markdown]
# Setelah kita melakukan tuning hyper-parameter disetiap metode machine learning konvensional mari kita perhatikan hasil akurasi untuk setiap metode dengan pengaturan hyperparameter terbaik:
#
# 1. **Naive Bayes: 0.72**
#    - Hyperparameter: `{'priors': None, 'var_smoothing': 1e-07}`
#
# 2. **Decision Tree: 0.86**
#    - Hyperparameter: `{'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}`
#
# 3. **KNN: 0.87**
#    - Hyperparameter: `{'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 9, 'p': 2, 'weights': 'distance'}`
#
# 4. **SVM: 0.88**
#    - Hyperparameter: `{'C': 1, 'class_weight': 'balanced', 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}`
#
# 5. **Logistic Regression: 0.86**
#    - Hyperparameter: `{'C': 0.001, 'max_iter': 1000, 'penalty': 'none', 'solver': 'saga'}`
#
# 6. **XGBoost: 0.90**
#    - Hyperparameter: `{'gamma': 0.2, 'learning_rate': 0.2, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100}`
#
# 7. **AdaBoost: 0.74**
#    - Hyperparameter: `{'algorithm': 'SAMME.R', 'base_estimator': DecisionTreeClassifier(max_depth=1), 'learning_rate': 0.1, 'n_estimators': 500, 'random_state': 42}`
#
# 8. **Random Forest: 0.97**
#    - Hyperparameter: `{'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}`
#
# 9. **Gradient Boosting: 0.89**
#    - Hyperparameter: `{'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}`
#
# Dari data diatas dapat kita lihat metode terbaik setelah tuning/setting hyper-parameternya **Random Forest** memiliki nilai akurasi yang paling tinggi dan memberikan kinerja yang baik sehingga dapat kita katakan metode **Random Forest** adalah metode yang terbaik untuk saat ini.Namun, keputusan tergantung pada kebutuhan spesifik tugas dan preferensi terkait interpretabilitas.
#
# Ada beberapa faktor untuk menentukan metode mana yang terbaik diantaranya:
#
# 1. **Performa Akurasi:**
#    - Random Forest memiliki akurasi tertinggi (0.97).
#    - Decision Tree, KNN, Logistic Regression, XGBoost dan Gradient Boosting memiliki akurasi yang baik (0.86 atau 0.90).
#    - Naive Bayes dan AdaBoost memiliki akurasi yang sedikit lebih rendah (0.72 atau 0.74).
#
# 2. **Pertimbangan Tambahan:**
#    - Jumlah hyperparameter: Model dengan lebih sedikit hyperparameter mungkin lebih mudah diatur dan lebih efisien untuk dilatih.
#    - Interpretabilitas: Beberapa model, seperti Decision Tree, lebih mudah diinterpretasikan daripada model kompleks seperti XGBoost.

# %% [markdown]
# ### 3.2.2 Hasil dari set-up hyper parameter terbaik setiap metode, bandingkan dengan antar metode. Mana yang paling baik? Jelaskan mengapa?

# %% [markdown]
# - Best score accuracy for Naive Bayes: **0.72**
# - Best score accuracy for Decision Tree: **0.86**
# - Best score accuracy for K-Nearest Neighbors : **0.87**
# - Best score accuracy for Support Vectore Machine : **0.88**
# - Best score accuracy for Logistic Regression: **0.86**
# - Best score accuracy for XGBoost: **0.90**
# - Best score accuracy for AdaBoost: **0.74**
# - Best score accuracy for Random Forest: **0.97**
# - Best score accuracy for Gradien Boosting: **0.89**
#
# Dari hasil akurasi , Random Forest memiliki akurasi tertinggi dengan nilai 0.97, diikuti oleh XGBoost dengan nilai 0.90. Kemudian, Gradien Boosting dengan akurasi 0.89, Support Vectore Machine dengan akurasi 0.88, diikuti oleh K-Nearest Neighbors yang memiliki akurasi 0.87, Logistic Regressin dan Decision tree memiliki akurasi yang sama yaitu 0.86 dan diikuti oleh AdaBoost dengan akurasi 0.74, dan terakhir adalah Naive Bayes dengan akurasi 0.72.
#
# Dari data diatas dapat kita lihat metode terbaik setelah tuning/setting hyper-parameternya **Random Forest** memiliki nilai akurasi yang paling tinggi dan memberikan kinerja yang baik sehingga dapat kita katakan metode **Random Forest** adalah metode yang terbaik untuk saat ini.Namun, keputusan tergantung pada kebutuhan spesifik tugas dan preferensi terkait interpretabilitas.

# %% [markdown]
# ### 3.2.3 (Bonus) Bandingkan jika menggunakan grid search. Apakah hasil yang diperoleh sama untuk hyperparameternya? Mengapa?

# %% [markdown]
# Jika Anda menggunakan teknik cross-validation dengan Grid Search untuk memilih hyperparameter, hasilnya dapat berbeda tergantung pada beberapa faktor. Meskipun tujuan utama Grid Search adalah menemukan kombinasi hyperparameter yang paling efisien, beberapa faktor dapat menyebabkan hasil yang berbeda:
#
# 1. Data Variabel
# Membagi data ke dalam subset pelatihan dan pengujian yang berbeda pada setiap iterasi cross-validation dapat menghasilkan hasil yang berbeda jika data Anda memiliki banyak variabilitas atau sifat stokastik.
#
# 2. Randomness dalam Algoritma
# Beberapa algoritma pembelajaran mesin memiliki elemen keacakan, terutama jika mereka menggunakan inisialisasi acak atau subsampling acak. Hal ini dapat menyebabkan variasi dalam hasil, terutama jika pencarian Grid memerlukan pemilihan parameter stokastik.
#
# 3. Ukuran kumpulan data
# Ukuran kumpulan data juga dapat mempengaruhi stabilitas hasil.Pada kumpulan data kecil, variasi dalam berbagi data dan pelatihan model dapat berdampak lebih besar.
#
# 4. Pilihan ukuran evaluasi
# Pilihan ukuran evaluasi dapat mempengaruhi hasil pencarian grid.Pengukuran yang berbeda dapat memberikan evaluasi yang berbeda untuk model yang sama.
#
# 5. Memilih ruang hyperparameter
# Jika ruang hyperparameter  yang dieksplorasi oleh Pencarian Grid  tidak cukup detail atau terlalu terbatas, hasilnya mungkin tidak menyertakan kombinasi hyperparameter yang optimal.
#
# Namun, meskipun hasilnya mungkin berbeda, pencarian grid dengan teknik validasi silang tetap bermanfaat dalam  evaluasi model.Penggunaannya membantu menghindari overfitting pada satu set pelatihan  dan memberikan estimasi performa model yang lebih baik  pada data yang tidak terlihat. Idealnya, saat menggunakan pencarian grid, Anda  tidak boleh hanya melihat  hasil tertentu namun mencoba memahami variasi hasil dan mengambil keputusan berdasarkan tren umum.
#
# Jika Anda menemukan bahwa hasilnya sangat bervariasi atau tidak konsisten, ini mungkin merupakan sinyal untuk  memeriksa dan memahami perilaku model Anda pada data yang berbeda secara lebih detail.
